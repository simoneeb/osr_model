# %%
from visualizations import plot_OSR_simulation,plot_slope
import json
from utils import load_dict

# %% [markdown]
# # Compare simulation with fixed vs dynamic occupancy

# %%
# simulation to load
simulation_name_dynamic = 'params_manual_N_dynamic_A1OFF20'

fn = 12

# %%
# import params
filepath_dynamic = f"/user/sebert/home/Documents/Repositories/osr_model/outputs/{simulation_name_dynamic}"
with open(f'{filepath_dynamic}/params.json') as json_file:
    params_dynamic = json.load(json_file)
    print(params_dynamic)
# Out:
# {'params_model': {'tau_B': 0.09, 'tau_A1': 0.13, 'tau_A2': 0.14, 'tau_G': 0.06, 'w_B': 30.0, 'w_A1': -20.0, 'w_A2': -30.0, 'theta_A1': -0.05, 'theta_A2': -0.05, 'k_rec': 10.0, 'k_rel': 10.0, 'beta': 16, 'scale_mV': 0.05, 'slope': 200, 'threshold': 0, 'SFB': 0.5555555555555556, 'SFA1': 0.3846153846153846, 'SFA2': 0.35714285714285715, 'n_A1_star': 0.5555555555555556, 'theta_B': -0.0685185185185185}, 'model_functions': {'linear_filter': '<function filter_alpha_norm at 0x7f6e0f3c6430>', 'system': '<function IPL_rectified_occupancy at 0x7f6e0f3c6700>', 'nonlinearity': '<function N at 0x7f6e0f3c68b0>'}, 'hyperparameter': {'dt': 0.02, 'filterlength': 1, 'occupancy': 'dynamic', 'polarities': ['ON', 'OFF', 'ON']}}

# %%
# import simulations
simulation_dynamic = load_dict(f'{filepath_dynamic}/simulation_osr_dynamic_{fn}.pickle')

# %%
simulations = [simulation_dynamic]
colors = ['black']
labels = [ 'dynamic occupancy']

# %%
# plot traces
plot_OSR_simulation(simulations,colors,labels)

# %%
plot_slope(simulations,colors,labels)

# %%
simulation_dynamic['maxs_n']
# Out:
# array([0.49999102, 0.48418655, 0.47236123, 0.45661434, 0.43674756])
